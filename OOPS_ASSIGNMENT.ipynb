# %% [markdown]
# THEORITICAL ANS:-

# %% [markdown]
# 1)What is Object-Oriented Programming (OOP)
#
# 2)What is a class in OOP
#
# 3)What is an object in OOP
#
# 4)What is the difference between abstraction and encapsulation
#
# 5)What are dunder methods in Python

# %% [markdown]
# ANS 1)OOP is a programming paradigm based on the concept of "objects", which contain data (attributes) and methods (functions) to operate on that data. It promotes code reuse and modularity.
#
# ANS 2)A class is a blueprint for creating objects. It defines attributes and methods that its objects will have.
#
# ANS 3)An object is an instance of a class. It holds actual values for the attributes defined in the class.
#
# ANS 4)Abstraction hides implementation details and shows only essential features.
#
# Encapsulation binds data and methods together and restricts access to some of the object's components.
#
# ANS 5)Dunder methods like __init__, __str__, and __len__ are special methods used to define behavior for built-in operations.

# %% [markdown]
#  6)Explain the concept of inheritance in OOP
#
#  7)What is polymorphism in OOP
#
#  8)How is encapsulation achieved in Python
#
# 9) What is a constructor in Python
#
# 10) What are class and static methods in Python

# %% [markdown]
# ANS 6)Inheritance allows one class (child) to acquire properties and methods of another class (parent), promoting code reuse.
#
# ANS 7)Polymorphism means the same method name can behave differently based on the object that invokes it.
#
# ANS 8)Encapsulation is achieved using private variables (prefixing with _ or __) and providing getter/setter methods.
#
# ANS 9)A constructor is a special method (__init__) called when an object is created to initialize its attributes.
#
# ANS 10)Class methods (@classmethod) receive the class as the first argument and can modify class state.
#
# Static methods (@staticmethod) do not access class or instance data.

# %% [markdown]
#  11)What is method overloading in Python
#
#  12)What is method overriding in OOP
#
#  13)What is a property decorator in Python
#
#  14)Why is polymorphism important in OOP
#
# 15) What is an abstract class in Python

# %% [markdown]
# ANS 11)Python does not support traditional method overloading. Instead, default or variable arguments are used to simulate it.
#
# What is method overriding in OOP?
#
# ANS 12)Method overriding occurs when a subclass provides a specific implementation of a method already defined in its parent class.
#
# What is a property decorator in Python?
#
# ANS 13)The @property decorator turns a method into a read-only property, allowing access like an attribute.
#
# Why is polymorphism important in OOP?
#
# ANS 14)It allows flexibility and integration by enabling a single interface to represent different types of objects.
#
# What is an abstract class in Python?
#
# ANS 15)An abstract class is a class that cannot be instantiated and often includes abstract methods that must be implemented in child classes, using the abc module.

# %% [markdown]
# 16) What are the advantages of OOP
#
# 17)What is multiple inheritance in Python
#
# 18)What is the difference between a class variable and an instance variable
#
# 19)Explain the purpose of ‘’__str__’ and ‘__repr__’ ‘ methods in Python
#
# 20)What is the significance of the ‘super()’ function in Python

# %% [markdown]
# ANS 16)Reusability through inheritance
#
# Modularity through encapsulation
#
# Maintainability and scalability
#
# Easier debugging and testing
#
# ANS 17)Multiple inheritance allows a class to inherit from more than one parent class.
#
#
#
# ANS 18)Class variables are shared among all instances.
#
# Instance variables are unique to each object.
#
#
# ANS 19)__str__ defines a human-readable representation.
#
# __repr__ defines an unambiguous representation useful for debugging.
#
# ANS 20)super() is used to call methods of the parent class, useful in inheritance and method overriding.

# %% [markdown]
#  21)What is the significance of the __del__ method in Python
#
#  22)What is the difference between @staticmethod and @classmethod in Python
#
#  23)How does polymorphism work in Python with inheritance
#
# 24) What is method chaining in Python OOP
#
#  25)What is the purpose of the __call__ method in Python?

# %% [markdown]
# ANS 21)__del__ is a destructor method called when an object is about to be destroyed, useful for cleanup.
#
# ANS 22)@staticmethod doesn’t access class or instance data.
#
# @classmethod accesses class data and takes cls as the first parameter.
#
# ANS 23)How does polymorphism work in Python with inheritance?
# It works by defining methods in the parent class and overriding them in the child class, allowing dynamic method resolution.
#
# ANS 24)Method chaining involves calling multiple methods on the same object in a single statement by returning self from each method.
#
# ANS 25)__call__ allows an object to be called as a function. It is used to make instances behave like functions.

# %% [markdown]
# PRACTICAL Q/A
#
#
#
# 1. Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog
# that overrides the speak() method to print "Bark!".
#
#
# 2. Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle
# from it and implement the area() method in both.
#
#
# 3. Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car
# and further derive a class ElectricCar that adds a battery attribute.
#
#
# 4. Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes
# Sparrow and Penguin that override the fly() method.
#
#
# 5. Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes
# balance and methods to deposit, withdraw, and check balance.

# %%
#1
class Animal:
    def speak(self):
        print("Animal makes a sound")

class Dog(Animal):
    def speak(self):
        print("Bark!")

# Example usage
a = Animal()
a.speak()

d = Dog()
d.speak()
# Out:
# Animal makes a sound
# Bark!

# %%
#2
from abc import ABC, abstractmethod
import math

class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * self.radius ** 2

class Rectangle(Shape):
    def __init__(self, width, height):
        self.width = width
        self.height = height

    def area(self):
        return self.width * self.height

# Example usage
circle = Circle(5)
print("Circle area:", circle.area())

rectangle = Rectangle(4, 6)
print("Rectangle area:", rectangle.area())
# Out:
# Circle area: 78.53981633974483
# Rectangle area: 24

# %%
#3
class Vehicle:
    def __init__(self, type):
        self.type = type

class Car(Vehicle):
    def __init__(self, type, brand):
        super().__init__(type)
        self.brand = brand

class ElectricCar(Car):
    def __init__(self, type, brand, battery):
        super().__init__(type, brand)
        self.battery = battery

# Example usage
ecar = ElectricCar("Four-wheeler", "Tesla", "100 kWh")
print("Type:", ecar.type)
print("Brand:", ecar.brand)
print("Battery:", ecar.battery)
# Out:
# Type: Four-wheeler
# Brand: Tesla
# Battery: 100 kWh

# %%
#4
class Bird:
    def fly(self):
        print("Bird is flying")

class Sparrow(Bird):
    def fly(self):
        print("Sparrow flies high")

class Penguin(Bird):
    def fly(self):
        print("Penguin cannot fly")

# Example usage
birds = [Sparrow(), Penguin()]
for bird in birds:
    bird.fly()
# Out:
# Sparrow flies high
# Penguin cannot fly

# %%
#5
class BankAccount:
    def __init__(self, initial_balance=0):
        self.__balance = initial_balance

    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print(f"Deposited: {amount}")
        else:
            print("Deposit amount must be positive")

    def withdraw(self, amount):
        if 0 < amount <= self.__balance:
            self.__balance -= amount
            print(f"Withdrew: {amount}")
        else:
            print("Insufficient funds or invalid amount")

    def check_balance(self):
        print(f"Current Balance: {self.__balance}")

# Example usage
account = BankAccount(1000)
account.deposit(500)
account.withdraw(200)
account.check_balance()
# Out:
# Deposited: 500
# Withdrew: 200
# Current Balance: 1300

# %%
#6
class Instrument:
    def play(self):
        print("Instrument is playing")

class Guitar(Instrument):
    def play(self):
        print("Guitar is strumming")

class Piano(Instrument):
    def play(self):
        print("Piano is playing keys")

# Example usage
instruments = [Guitar(), Piano()]
for instrument in instruments:
    instrument.play()
# Out:
# Guitar is strumming
# Piano is playing keys

# %%
#7
class MathOperations:
    @classmethod
    def add_numbers(cls, a, b):
        return a + b

    @staticmethod
    def subtract_numbers(a, b):
        return a - b

# Example usage
print("Addition:", MathOperations.add_numbers(10, 5))
print("Subtraction:", MathOperations.subtract_numbers(10, 5))
# Out:
# Addition: 15
# Subtraction: 5

# %%
#8
class Person:
    count = 0

    def __init__(self, name):
        self.name = name
        Person.count += 1

    @classmethod
    def get_count(cls):
        return cls.count

# Example usage
p1 = Person("Alice")
p2 = Person("Bob")
p3 = Person("Charlie")

print("Total Persons:", Person.get_count())
# Out:
# Total Persons: 3

# %%
#9
class Fraction:
    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator

    def __str__(self):
        return f"{self.numerator}/{self.denominator}"

# Example usage
f = Fraction(3, 4)
print("Fraction:", f)
# Out:
# Fraction: 3/4

# %%
#10
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)

    def __str__(self):
        return f"({self.x}, {self.y})"

# Example usage
v1 = Vector(2, 3)
v2 = Vector(4, 5)
v3 = v1 + v2

print("Vector Sum:", v3)
# Out:
# Vector Sum: (6, 8)

# %%
#11
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

# Example usage
p = Person("Alice", 30)
p.greet()
# Out:
# Hello, my name is Alice and I am 30 years old.

# %%
#12
class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades  # List of numbers

    def average_grade(self):
        if self.grades:
            return sum(self.grades) / len(self.grades)
        return 0

# Example usage
s = Student("Bob", [85, 90, 78])
print(f"{s.name}'s average grade:", s.average_grade())
# Out:
# Bob's average grade: 84.33333333333333

# %%
#13
class Rectangle:
    def __init__(self):
        self.width = 0
        self.height = 0

    def set_dimensions(self, width, height):
        self.width = width
        self.height = height

    def area(self):
        return self.width * self.height

# Example usage
r = Rectangle()
r.set_dimensions(5, 10)
print("Area of rectangle:", r.area())
# Out:
# Area of rectangle: 50

# %%
#14
class Employee:
    def __init__(self, hours_worked, hourly_rate):
        self.hours_worked = hours_worked
        self.hourly_rate = hourly_rate

    def calculate_salary(self):
        return self.hours_worked * self.hourly_rate

class Manager(Employee):
    def __init__(self, hours_worked, hourly_rate, bonus):
        super().__init__(hours_worked, hourly_rate)
        self.bonus = bonus

    def calculate_salary(self):
        return super().calculate_salary() + self.bonus

# Example usage
e = Employee(40, 20)
print("Employee Salary:", e.calculate_salary())

m = Manager(40, 30, 500)
print("Manager Salary:", m.calculate_salary())
# Out:
# Employee Salary: 800
# Manager Salary: 1700

# %%
#15
class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    def total_price(self):
        return self.price * self.quantity

# Example usage
p = Product("Laptop", 800, 2)
print(f"Total price of {p.name}: ${p.total_price()}")
# Out:
# Total price of Laptop: $1600

# %%
#16
from abc import ABC, abstractmethod

class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass

class Cow(Animal):
    def sound(self):
        return "Moo"

class Sheep(Animal):
    def sound(self):
        return "Baa"

# Example usage
cow = Cow()
sheep = Sheep()

print("Cow:", cow.sound())
print("Sheep:", sheep.sound())
# Out:
# Cow: Moo
# Sheep: Baa

# %%
#17
class Book:
    def __init__(self, title, author, year_published):
        self.title = title
        self.author = author
        self.year_published = year_published

    def get_book_info(self):
        return f"'{self.title}' by {self.author} (Published in {self.year_published})"

# Example usage
book = Book("1984", "George Orwell", 1949)
print(book.get_book_info())
# Out:
# '1984' by George Orwell (Published in 1949)

# %%
#18
class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price

class Mansion(House):
    def __init__(self, address, price, number_of_rooms):
        super().__init__(address, price)
        self.number_of_rooms = number_of_rooms

# Example usage
mansion = Mansion("123 Luxury St", 2500000, 12)
print(f"Mansion located at {mansion.address}, Price: ${mansion.price}, Rooms: {mansion.number_of_rooms}")
# Out:
# Mansion located at 123 Luxury St, Price: $2500000, Rooms: 12
